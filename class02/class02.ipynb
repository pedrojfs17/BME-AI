# %% [markdown]
# **This class was made with Rita Matos Maranhão Peixoto**

# %%
from skimage import measure
import numpy as np
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from mpl_toolkits.mplot3d import Axes3D
import sklearn
import sklearn.cluster
import itertools
import statistics
import cv2
import scipy
import plotly.graph_objs as go
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = mpimg.imread("DSC_2144.jpg")
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ## Segmentation

# %%
gimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gimg,cmap='gray')
plt.show()

# %%
plt.hist(gimg.flatten(),bins=25);

# %% [markdown]
# ### Mean

# %%
print(gimg.mean())
# Out:
# 140.67478916666667

# %% [markdown]
# ### Otsu
# <pre>threshold(src, thresh, maxval, type[, dst])</pre>

# %%
thr,res = cv2.threshold(gimg,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
print(thr)
# Out:
# 107.0

# %%
figure_size = 15
plt.figure(figsize=(figure_size,figure_size))
plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(res)
plt.title('Segmented Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### TASK: segment the image according to mean

# %% [markdown]
# ### k-means clustering in RGB space

# %%
r = img[::20,::20,0].flatten()
g = img[::20,::20,1].flatten()
b = img[::20,::20,2].flatten()
np.shape(r)
# Out:
# (6000,)

# %%
plt.imshow(img[:,:,2],cmap='gray')
plt.show()

# %% [markdown]
# ### RGB space

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(r, g, b)
plt.show()

# %%
sc = go.Scatter3d(x=r,y=g,z=b,mode="markers",\
                  marker=dict(size=2,color=np.array([r,g,b]).T))
fig = go.Figure(sc)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="173669ce-8b3e-4215-878e-6bc142ce7d51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("173669ce-8b3e-4215-878e-6bc142ce7d51")) {                    Plotly.newPlot(                        "173669ce-8b3e-4215-878e-6bc142ce7d51",                        [{"marker":{"color":[[114,151,221],[106,143,211],[106,143,213],[106,143,211],[106,143,213],[103,142,209],[103,142,211],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[106,145,212],[104,143,210],[104,143,210],[107,144,214],[106,145,212],[109,146,216],[107,144,214],[106,145,212],[106,145,212],[106,145,212],[108,145,215],[106,145,212],[108,145,215],[106,145,212],[104,143,210],[104,143,210],[105,145,214],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,210],[104,143,212],[103,142,211],[105,142,212],[105,142,212],[102,141,210],[102,141,210],[101,140,209],[98,143,210],[105,138,209],[104,136,197],[89,114,168],[201,212,232],[98,139,203],[102,139,207],[102,139,209],[102,141,210],[103,142,211],[103,142,211],[104,143,212],[104,143,210],[103,142,211],[105,144,211],[103,142,211],[103,142,211],[106,143,213],[103,142,211],[103,142,211],[103,142,211],[106,143,213],[105,142,212],[106,143,213],[106,143,211],[106,143,213],[106,143,213],[106,143,213],[106,143,211],[106,143,213],[106,143,211],[104,141,211],[106,143,211],[105,142,210],[106,143,211],[106,143,211],[105,142,210],[105,142,210],[105,142,210],[106,140,211],[106,140,211],[105,143,205],[107,143,205],[105,143,205],[105,143,206],[105,143,206],[105,143,205],[107,145,207],[106,143,211],[96,134,197],[96,134,199],[96,134,199],[97,135,200],[97,135,200],[97,135,200],[95,134,199],[95,134,199],[95,134,199],[95,134,199],[95,134,199],[96,134,199],[95,134,199],[96,134,199],[96,134,199],[96,134,199],[95,134,199],[96,134,199],[95,134,199],[96,134,199],[97,135,200],[96,134,199],[97,135,200],[95,134,199],[96,134,199],[96,134,199],[95,134,199],[97,135,200],[95,134,199],[96,134,199],[95,134,199],[95,134,199],[95,134,199],[95,134,199],[95,134,199],[96,135,200],[94,133,198],[95,134,199],[95,134,199],[95,134,199],[94,133,198],[95,134,199],[95,134,199],[96,134,199],[95,134,199],[93,133,195],[93,131,194],[90,129,194],[89,129,191],[89,127,190],[87,125,187],[178,197,229],[136,157,200],[163,178,217],[217,224,242],[220,228,241],[132,156,194],[84,124,185],[87,125,187],[89,128,193],[91,131,193],[93,133,195],[94,133,198],[94,133,198],[95,134,199],[95,134,199],[94,133,198],[95,134,199],[95,134,199],[95,134,199],[96,134,199],[96,134,199],[96,134,199],[94,133,198],[95,133,198],[96,134,199],[96,134,199],[95,133,198],[95,133,198],[96,134,197],[95,133,196],[96,134,197],[96,134,199],[96,134,197],[95,133,196],[96,134,197],[98,133,197],[95,133,196],[95,133,196],[95,133,196],[97,132,196],[97,132,196],[94,132,195],[95,130,194],[96,132,192],[94,133,190],[94,133,190],[96,132,192],[94,133,190],[108,145,215],[97,135,200],[98,136,201],[97,135,200],[95,136,200],[98,136,201],[95,136,200],[95,136,200],[95,136,200],[95,136,200],[100,138,203],[95,136,200],[95,136,200],[98,136,201],[96,137,201],[96,137,201],[98,136,201],[98,136,201],[95,136,200],[98,136,201],[96,137,201],[97,135,200],[97,135,200],[99,137,202],[98,136,201],[98,136,201],[98,136,201],[98,136,201],[96,137,201],[96,137,201],[96,137,201],[96,137,201],[96,137,201],[95,136,200],[95,136,200],[95,136,202],[95,136,202],[95,136,200],[95,136,200],[95,136,202],[95,136,200],[95,136,200],[95,136,200],[95,136,200],[95,136,200],[93,134,196],[94,132,195],[92,130,193],[91,129,192],[91,129,192],[89,127,189],[87,125,187],[118,143,197],[167,190,224],[194,206,230],[200,211, ...

# %% [markdown]
# ### K-means clustering
# Segment the image into two parts using k-means clustering
#
# First we need to flatten the 2d image

# %%
print(img.shape)
print(img.reshape((-1,3)).shape)
# Out:
# (1200, 2000, 3)
# (2400000, 3)

# %% [markdown]
# ### Warning
# You can stop the next command if it takes too long! And this is just a 2.4 megapixel image!

# %%
K = 2
rgb = img.reshape((-1,3))
kmeans = sklearn.cluster.KMeans(n_clusters=K).fit(rgb)

# %%
kmeans.cluster_centers_
# Out:
# array([[145.10463975, 162.37266282, 188.83538331],
#        [ 39.8745186 ,  44.43616846,  50.06838625]])

# %%
a = 255/(K-1)
kres = np.array(kmeans.predict(np.array([r,g,b]).T))
sc = go.Scatter3d(x=r,y=g,z=b,mode="markers",\
                  marker=dict(size=2,color=np.array([kres*a,255-kres*a,kres*0]).T))
fig = go.Figure(sc)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a4a93ce0-7255-42b7-84b4-884093870f2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4a93ce0-7255-42b7-84b4-884093870f2e")) {                    Plotly.newPlot(                        "a4a93ce0-7255-42b7-84b4-884093870f2e",                        [{"marker":{"color":[[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255.0,0.0],[0.0,255. ...

# %%
D = 10
sm_img = img[::D,::D,:]
rgb = sm_img.reshape((-1,3))
np.shape(rgb)
kmeans = sklearn.cluster.KMeans(n_clusters=2).fit(rgb)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 39.52706711,  44.06803856,  49.71968854],
#        [145.00360099, 162.43674084, 189.27421262]])

# %% [markdown]
# Now the real clustering but using the centers from the decimated. It is faster in two steps.

# %%
rgb = img.reshape((-1,3))
kmeans = sklearn.cluster.KMeans(n_clusters=2,init=kmeans.cluster_centers_,n_init=1).fit(rgb)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 39.83445675,  44.39222852,  50.01636005],
#        [145.09330817, 162.35968416, 188.82020686]])

# %% [markdown]
# Cluster the ponts of the images

# %%
pred = kmeans.predict(rgb)
res = pred.reshape((1200,2000))
np.shape(res)
# Out:
# (1200, 2000)

# %%
figure_size = 15
plt.figure(figsize=(figure_size,figure_size))
plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(res)
plt.title('Segmented Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
figure_size = 15
plt.figure(figsize=(figure_size,figure_size))
plt.subplot(1,2,1),plt.imshow(img[800:1000,740:1300])
plt.title('Original Image zoom'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(res[800:1000,740:1300])
plt.title('Segmented Image zoom'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Find connected components

# %%
regions = measure.label(res,connectivity=1,background=-10)
patches = measure.regionprops(regions)

# %% [markdown]
# ### Boundary box
# y_min, x_min, y_max, x_max

# %%
print(patches[5].area, patches[5].bbox)
# Out:
# 24 (285, 806, 290, 814)

# %% [markdown]
# ### TASK: select regions which fulfill the following conditions
#  * area > 100
#  * area < 0.3 * area of the whole image
#  * aspect ratio is between 2 and 5 and lying flat
#
#  1. Draw rectangles around the objects
#  2. Plot the corresponding part from the original image
#    * matplotlib.patches.Rectangle( (x0, y0), w, h )
#    * see example below

# %%
matching_patches = []

for p in patches:
  p_width = p.bbox[3] - p.bbox[1]
  p_height = p.bbox[2] - p.bbox[0]
  aspect_ratio = p_width / p_height

  if p.area > 100 and p.area < 0.3 * res.shape[0] * res.shape[1] and aspect_ratio >= 2 and aspect_ratio <= 5:
    matching_patches.append([(p.bbox[1], p.bbox[0]), p_width, p_height])
  
len(matching_patches)
matching_patches
# Out:
# [[(1200, 529), 493, 114],
#  [(657, 545), 582, 141],
#  [(749, 546), 31, 15],
#  [(662, 550), 59, 18],
#  [(1461, 557), 49, 19],
#  [(0, 560), 1642, 411],
#  [(745, 667), 105, 44],
#  [(431, 670), 97, 29],
#  [(256, 672), 200, 79],
#  [(1387, 690), 243, 63],
#  [(166, 692), 24, 12],
#  [(1111, 719), 128, 49],
#  [(508, 720), 186, 44],
#  [(552, 720), 61, 14],
#  [(698, 736), 167, 62],
#  [(569, 741), 39, 13],
#  [(906, 763), 1006, 366],
#  [(247, 791), 33, 9],
#  [(180, 814), 187, 38],
#  [(742, 819), 100, 33],
#  [(1014, 833), 49, 21],
#  [(1065, 841), 202, 55],
#  [(1381, 842), 246, 99],
#  [(1396, 880), 209, 60]]

# %%
#plot rectangle example, important! Rectangle requires width and height
#Here it is unimportant but origin is at top left corner!

fig, (ax1) = plt.subplots(1,figsize=(20,20))
plt.xticks([]),plt.yticks([])
ax1.imshow(res);

for patch in matching_patches:
  rectBorder = matplotlib.patches.Rectangle(patch[0], patch[1], patch[2], edgecolor="red", linewidth=2, fill=False)
  ax1.add_patch(rectBorder)

plt.show()

# %% [markdown]
# ## Pattern matching

# %%
fig, ax = plt.subplots()
ax.imshow(gimg[863:881,1067:1083],cmap='gray');

# %% [markdown]
# ### Create pattern

# %%
template = gimg[863:881,1067:1083]
w, h = template.shape[::-1]

# %% [markdown]
# ### Find pattern

# %%
res = cv2.matchTemplate(gimg,template,cv2.TM_CCOEFF_NORMED)

# %%
np.shape(res)
# Out:
# (1183, 1985)

# %% [markdown]
# ### Fantastic beasts and where to find them

# %%
gimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(res,cmap='gray')
plt.show()

# %%
threshold = 0.50
loc = np.where( res >= threshold)
print(loc)
# Out:
# (array([861, 862, 863, 864, 865]), array([1067, 1067, 1067, 1067, 1067]))

# %% [markdown]
# ### TASK
#  1. plot the corresponding parts of the image
#  2. decrease the threshold to 0.6, 0.5, 0.45 (do not go much below!)

# %%
match_count = len(loc[0])
fig2, axs = plt.subplots(math.ceil(match_count / 5), 5)

for i in range(match_count):
  x = loc[0][i]
  y = loc[1][i]
  if match_count <= 5: axs[i % 5].imshow(gimg[x:x+w,y:y+h],cmap='gray');
  else: axs[i // 5, i % 5].imshow(gimg[x:x+w,y:y+h],cmap='gray');

# %% [markdown]
# ### TASK
#  1. write a code which resizes the pattern (factors: 0.5-2) and searches for its matches, can you find the other H?
# <pre>cv2.resize(template,new_x,new_y)</pre> does the trick
#  2. plot the found plate number with the numbers included (just estimate the size)

# %%
scale = 0.5 # percent of original size
width = int(template.shape[1] * scale)
height = int(template.shape[0] * scale)
dim = (width, height)

resized = cv2.resize(template, dim)
w, h = resized.shape[::-1]

res = cv2.matchTemplate(gimg,resized,cv2.TM_CCOEFF_NORMED)

threshold = 0.50
loc = np.where( res >= threshold)

match_count = len(loc[0])
print(match_count)

for i in range(match_count):
  x = loc[0][i]
  y = loc[1][i]

  # We know the other plate is between this values, so we can filter them to make our work easier
  if x > 700 and x < 900 and y > 700 and y < 800:
    print((x, y))
    fig2, axs = plt.subplots()
    axs.imshow(gimg[x:x+w,y:y+h],cmap='gray');
# Out:
# 48
# (832, 746)
# (833, 746)

# %% [markdown]
# From the patches found earlier, we can easily get the plates

# %%
plates = [
 [(742, 819), 100, 33],
 [(1065, 841), 202, 55]
]

for plate in plates:
  (x, y), w, h = plate

  fig, ax = plt.subplots()
  ax.imshow(gimg[y:y+h,x:x+w],cmap='gray');

# %% [markdown]
# ## Homework
# Try to find the letters on the number plates. Please note, that any other route is possible, I even encourage you to try to find better methods if you have the ambition.
# By the end of the class after thresholding and looking for horizontal patches you should end up with about two dozen of them matching the criteria. Go through them and perform the following:
# * Use k-means clustering with k=2 on these rectangles. If the original patch was a number plate we expect this to find letters and other dirt. Let us call smallpatches these patches found on the patches.
# * Discard smallpatches which:
#    - are larger than 1/5th of the patch
#    - are smaller than 1/100th of the patch
#    - are shorter than the half of the patch (in the vertical direction)
#    - have an aspect ratio < 0.1
#    - have an aspect ratio > 1.2
#    - have less than 4 or more than 10 smallpatches matching the above criteria.
#
# * Finally keep only those patches the relative height of which differs less than 5% from the median
#
# Check the images rendszam*.png in the zip file. These are the images I recieved with and without the last rule
